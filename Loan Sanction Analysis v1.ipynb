# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import statistics as stat
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r"C:\Users\rvidivada\Desktop\Python\Mini Projects\Project Files\EDA\Loan santion\loan_sanction.xlsx")
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
#1. Check how many duplicate rows are present
df.duplicated().sum()
# Out:
# 3

# %%
#2. If any Duplicates Present, drop those duplicates
df=df.drop_duplicates()
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
#3. Check null values in each column
df.isna().sum()
# Out:
# Loan_ID                0
# Gender                 2
# Married                0
# Dependents            11
# Education              0
# Self_Employed          0
# Applicant_Income       0
# Coapplicant_Income     0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area          0
# dtype: int64

# %%
#4. Delete the Rows which are having null values.
del_missing_values = df.dropna()
del_missing_values
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
#5. Impute null values with Mode in Gender Column
mode_gender = df['Gender'].mode()[0]
df['Gender'].fillna(mode_gender, inplace = True)
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
#6. Impute null values with Mode in Self_Employed Column
mode_selfemployed=df['Self_Employed'].mode()[0]
df['Self_Employed'].fillna(mode_selfemployed, inplace = True)

# %%
df['LoanAmount']=pd.to_numeric(df['LoanAmount'], errors = 'coerce')
df['Credit_History']=pd.to_numeric(df['Credit_History'], errors = 'coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 367 entries, 0 to 369
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loan_ID             367 non-null    object
#  1   Gender              367 non-null    object
#  2   Married             367 non-null    object
#  3   Dependents          356 non-null    object
#  4   Education           367 non-null    object
#  5   Self_Employed       367 non-null    object
#  6   Applicant_Income    367 non-null    object
#  7   Coapplicant_Income  367 non-null    int64
#  8   LoanAmount          365 non-null    float64
#  9   Loan_Amount_Term    367 non-null    int64
#  10  Credit_History      366 non-null    float64
#  11  Property_Area       367 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 37.3+ KB

# %%
#7. Impute null values with mean in LoanAmount Column
mean_loanamount = df['LoanAmount'].mean()
df['LoanAmount'].fillna(mean_loanamount, inplace = True)

# %%
#8. Top 5 Records
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male                  2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#   Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0             5720                   0       110.0               360
# 1             3076                1500       126.0               360
# 2             5000                1800       208.0               360
# 3             2340                2546       100.0               360
# 4             3276                   0        78.0               360
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
#9. Export the dataframe in excel.
df.to_excel('Loan_Sanction_Analysis_EDA_Project.xlsx')

# %%
#10. Number of Rows and Columns in a DataFrame
df.shape
# Out:
# (367, 12)

# %%
#11. Print all Column names in a DF
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Applicant_Income', 'Coapplicant_Income', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
#12. Generate the descriptive statistics of Numerical variables.
df.describe()
# Out:
#        Coapplicant_Income   LoanAmount  Loan_Amount_Term  Credit_History
# count          367.000000   365.000000        367.000000      366.000000
# mean          1569.577657   162.975342        342.822888        1.147541
# std           2334.232099   519.959679         64.658402        2.822625
# min              0.000000   -88.000000          6.000000        1.000000
# 25%              0.000000   102.000000        360.000000        1.000000
# 50%           1025.000000   125.000000        360.000000        1.000000
# 75%           2430.500000   158.000000        360.000000        1.000000
# max          24000.000000  9999.000000        480.000000       55.000000

# %%
#13. Display numeric data type columns in a DF
df_numeric = [i for i in df.columns if df[i].dtypes!='object']
df_numeric
# Out:
# ['Coapplicant_Income', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
#14. Select all datdf[df_numeric]a types of columns in a DF except object data type.
df[df_numeric]
# Out:
#      Coapplicant_Income  LoanAmount  Loan_Amount_Term  Credit_History
# 0                     0       110.0               360             1.0
# 1                  1500       126.0               360             1.0
# 2                  1800       208.0               360             1.0
# 3                  2546       100.0               360             1.0
# 4                     0        78.0               360             1.0
# ..                  ...         ...               ...             ...
# 365                1777       113.0               360             1.0
# 366                 709       115.0               360             1.0
# 367                1993       126.0               360             1.0
# 368                2393       158.0               360             1.0
# 369                   0        98.0               180             1.0
#
# [367 rows x 4 columns]

# %%
#15. Extract all the Records where Self_Employed is equal to Yes.
df[df['Self_Employed']=='Yes']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 6    LP001054    Male     Yes          0  Not Graduate           Yes
# 38   LP001210       ?     Yes          0      Graduate           Yes
# 39   LP001211    Male      No          0      Graduate           Yes
# 50   LP001270    Male     Yes         3+  Not Graduate           Yes
# 63   LP001335    Male     Yes          0      Graduate           Yes
# 75   LP001380    Male     Yes          0      Graduate           Yes
# 79   LP001413    Male      No          0      Graduate           Yes
# 92   LP001475    Male     Yes          0      Graduate           Yes
# 112  LP001584  Female       #          0      Graduate           Yes
# 134  LP001728    Male     Yes          1      Graduate           Yes
# 145  LP001791    Male     Yes          0      Graduate           Yes
# 146  LP001794    Male     Yes          2      Graduate           Yes
# 149  LP001817    Male      No          0  Not Graduate           Yes
# ...

# %%
#16. Extract all the Records where Property_area is equal to urban in a DF.
df[df['Property_Area']=='Urban']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male                  2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 359  LP002935    Male     Yes          1      Graduate            No
# 360  LP002952    Male      No          0      Graduate            No
# 363  LP002965  Female     Yes          0      Graduate            No
# 365  LP002971    Male     Yes         3+  Not Graduate           Yes
# 366  LP002975    Male     Yes          0      Graduate            No
#
#     Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#17. Print number of unique vaues in Gender column
df['Gender'].nunique()
# Out:
# 3

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', '?'], dtype=object)

# %%
df[df['Gender']=='?']
# Out:
#      Loan_ID Gender Married Dependents Education Self_Employed  \
# 38  LP001210      ?     Yes          0  Graduate           Yes
#
#    Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 38             2267                2792        90.0               360
#
#     Credit_History Property_Area
# 38             1.0         Urban

# %%
#18. Check outliers in Loan amount and credit history column and replace them with mean.
#identify the mean
LoanAmount_mean = df['LoanAmount'].mean()
Credit_History_mean =df['Credit_History'].mean()

#identify the SD
LoanAmount_std = df['LoanAmount'].std()
Credit_History_std =df['Credit_History'].std()

#Assuming outlier threshold
outlier_threshold = 3

loanAmount_outliers = (df['LoanAmount']-LoanAmount_mean).abs()>outlier_threshold*LoanAmount_std
Credit_History_Outliers =(df['Credit_History']-Credit_History_mean).abs()>outlier_threshold*Credit_History_std

#Replacing outliers with the mean value
df.loc[loanAmount_outliers,'LoanAmount']=LoanAmount_mean
df.loc[Credit_History_Outliers,'Credit_History']=Credit_History_mean

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0               5720                   0       110.0               360
# ...

# %%
df.describe().round(2)
# Out:
#        Coapplicant_Income  LoanAmount  Loan_Amount_Term  Credit_History
# count              367.00      365.00            367.00          366.00
# mean              1569.58      136.03            342.82            1.00
# std               2334.23       61.97             64.66            0.01
# min                  0.00      -88.00              6.00            1.00
# 25%                  0.00      102.00            360.00            1.00
# 50%               1025.00      125.00            360.00            1.00
# 75%               2430.50      158.00            360.00            1.00
# max              24000.00      550.00            480.00            1.15

# %%
#19. Check for correlations of all variables.
df.select_dtypes(include='number').corr().round()
# Out:
#                     Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# Coapplicant_Income                 1.0         0.0              -0.0
# LoanAmount                         0.0         1.0               0.0
# Loan_Amount_Term                  -0.0         0.0               1.0
# Credit_History                    -0.0        -0.0               0.0
#
#                     Credit_History
# Coapplicant_Income            -0.0
# LoanAmount                    -0.0
# Loan_Amount_Term               0.0
# Credit_History                 1.0
